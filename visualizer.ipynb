# %% [markdown]
# # 2D Power Doppler Visualizer

# %%
import ui
import numpy as np 
import importlib
from scipy.io import loadmat
import visualization

importlib.reload(ui)
importlib.reload(visualization)

data = loadmat('file.mat')['var']

ui.power2D(data)
# Out:
# HBox(children=(VBox(children=(VBox(children=(IntRangeSlider(value=(0, 1250), continuous_update=False, descript…

# %% [markdown]
# # 3D Power Doppler Visualizer

# %%
import ui
import numpy as np 
import importlib
from scipy.io import loadmat

importlib.reload(ui)

data = loadmat('file.mat')['var']

spacing = (1, 1, 1)
origin = (0, 0, 0)

ui.power3D(data, spacing, origin)
# Out:
# --------------------------------------------------------------------------------
#   Date: Fri Aug 15 07:41:09 2025 Mountain Daylight Time
#
#                   OS : Windows (11 10.0.26100 SP0 Multiprocessor Free)
#               CPU(s) : 32
#              Machine : AMD64
#         Architecture : 64bit
#                  RAM : 31.2 GiB
#          Environment : Jupyter
#           GPU Vendor : NVIDIA Corporation
#         GPU Renderer : NVIDIA GeForce RTX 4070 Laptop GPU/PCIe/SSE2
#          GPU Version : 4.5.0 NVIDIA 576.88
#        Render Window : vtkWin32OpenGLRenderWindow
#     MathText Support : True
#
#   Python 3.13.4 (tags/v3.13.4:8a526ec, Jun  3 2025, 17:46:04) [MSC v.1943 64
#   bit (AMD64)]
#
#              pyvista : 0.45.2
#                  vtk : 9.4.2
#                numpy : 2.2.6
#           matplotlib : 3.10.3
#               scooby : 0.10.1
#                pooch : 1.8.2
#               pillow : 11.2.1
#              imageio : 2.37.0
#              IPython : 9.3.0
#             colorcet : 3.1.0
#              cmocean : 4.0.3
#           ipywidgets : 8.1.7
#                scipy : 1.15.3
#                 tqdm : 4.67.1
#               meshio : 5.3.5
#           jupyterlab : 4.4.3
#                trame : 3.10.2
#         trame_client : 3.9.1
#         trame_server : 3.4.2
#            trame_vtk : 2.8.17
#        trame_vuetify : 3.0.1
# jupyter_server_proxy : 4.4.0
#         nest_asyncio : 1.6.0
# --------------------------------------------------------------------------------
# Widget(value='<iframe src="http://localhost:53043/index.html?ui=P_0x22edac66cf0_0&reconnect=auto" class="pyvis…
# VBox(children=(IntSlider(value=115, continuous_update=False, description='slice 1:', max=231, style=SliderStyl…
